# %%
from generate import *

# %%
enkhuizen_yard = ShuntingYard(
    "ins_nt_enk", 
    "dom_nt_3",
    True, # is_temporal
    True, # is_numeric
    DirectionStrategy.NO_DIRECTION, # default direction Aside
    False, # negative_preconditions
    TrackOccupationStrategy.STACK_LOCATION, # how to model where trains are
    GoalStates.IS_PARKING, # how ot model goalstates
    1, # max concurrent movements
)
enkhuizen_yard.from_json('location_enkhuizen.json', include_switches=False)
# enkhuizen_yard.set_drivers(["Andy"])
enkhuizen_yard.remove_track('t_EH')
enkhuizen_yard.set_entry_track_connections(['t_401', 't_402', 't_403'], True)
enkhuizen_yard.set_trains([
    ("ddz_1", 160, 10, True),
    ("ddz_2", 160, 10, True),
    ("ddz_3", 160, 10, True),
    ("ddz_4", 160, 10, True),
    ("ddz_5", 160, 10, True),
    ("ddz_6", 160, 10, True),
    ("ddz_7", 160, 10, True),
    ("ddz_8", 160, 10, True),
    ("ddz_9", 160, 10, True),
    ("ddz_10", 160, 10, True),
    ("ddz_11", 160, 10, True),
    ("ddz_12", 160, 10, True),
    ("ddz_13", 160, 10, True),
    ("ddz_14", 160, 10, True),
    ("ddz_15", 160, 10, True),
    ("ddz_16", 160, 10, True),
    ("ddz_17", 160, 10, True),
    ("ddz_18", 160, 10, True),
    ("ddz_19", 160, 10, True),
    ("ddz_20", 160, 10, True),
    # ("ddz_21", 160, 10, True),
])
enkhuizen_yard.generate_instance()
enkhuizen_yard.visualize(figsize=(12,8))
# Out:
# 15

# %%
heerlen_yard = ShuntingYard(
    "ins_nt_enk", 
    "dom_nt_1",
    True, # is_temporal
    True, # is_numeric
    True, # default direction Aside
    False, # negative_preconditions
    TrackOccupationStrategy.STACK_LOCATION, # how to model where trains are
    GoalStates.HAS_PARKED,
)
heerlen_yard.from_json('location_heerlen.json', include_switches=False)
# heerlen_yard.set_entry_track_connections(['t_EH'], True)
heerlen_yard.set_trains([
    ("ddz_1", 160, 10, True),
    ("ddz_2", 160, 10, True),
    ("ddz_3", 160, 10, True),
    # ("ddz_4", 160, 10, True),
    # ("ddz_5", 160, 10, True),
    # ("ddz_6", 160, 10, True),
    # ("ddz_7", 160, 10, True),
    # ("ddz_8", 160, 10, True),
    # ("ddz_9", 160, 10, True),
    # ("ddz_10", 160, 10, True),
    # ("ddz_11", 160, 10, True),
    # ("ddz_12", 160, 10, True),
    # ("ddz_13", 160, 10, True),
    # ("ddz_14", 160, 10, True),
    # ("ddz_15", 160, 10, True),
    # ("ddz_16", 160, 10, True),
    # ("ddz_17", 160, 10, True),
    # ("ddz_18", 160, 10, True),
    # ("ddz_19", 160, 10, True),
    # ("ddz_20", 160, 10, True),
    # ("ddz_21", 160, 10, True),
])
# enkhuizen_yard.generate_instance()
heerlen_yard.visualize()

# %%
heerlen_yard = ShuntingYard('ins_n_hee', 'dom_neg_6')
heerlen_yard.from_json('location_heerlen.json')
heerlen_yard.remove_track('t_222e')
heerlen_yard.remove_track('t_223e')
heerlen_yard.set_entry_track_connections(['t_221', 't_222', 't_223', 't_224', 't_225', 't_226'], False)
heerlen_yard.set_trains([
    ("ddz_1", 160, 10, True),
    ("ddz_2", 160, 10, True),
    ("ddz_3", 160, 10, True),
    ("ddz_4", 160, 10, True),
    ("ddz_5", 160, 10, True),
    ("ddz_6", 160, 10, True),
    ("ddz_7", 160, 10, True),
    ("ddz_8", 160, 10, True),
    ("ddz_9", 160, 10, True),
    ("ddz_10", 160, 10, True),
    ("ddz_11", 160, 10, True),
    ("ddz_12", 160, 10, True),
    # ("ddz_13", 160, 10, True),
    # ("ddz_14", 160, 10, True),
    # ("ddz_15", 160, 10, True),
    # ("ddz_16", 160, 10, True),
    # ("ddz_17", 160, 10, True),
    # ("ddz_18", 160, 10, True),
    # ("ddz_19", 160, 10, True),
    # ("ddz_20", 160, 10, True),
    # ("ddz_21", 160, 10, True),
])
heerlen_yard.generate_instance()

# %%
heerlen_yard.visualize(figsize=(20,12))

# %%
heerlen_yard.visualize_track('t_223')
